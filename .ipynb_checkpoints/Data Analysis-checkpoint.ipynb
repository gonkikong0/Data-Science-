# %%
#modules

import pandas as pd

# %% [markdown]
# Dive into Data Science - 10/11/2025
# ## Pandas
# Pandas is an open source Python library used for manipulating and analyzing data.
# ### Exploratory Analysis -
# Initial stage of Analysis, in which the data is sophistically analyzed, cleaned and processed.
# #### .head()
# Used to print the first n number of rows and columns (Default: 5)
# #### .tail()
# Used to print the last n number of rows and columns (Deafault: 5)

# %%
hour = pd.read_csv('hour.csv')
print(hour.head())
print(hour.tail())
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  count
# 0           1  0.24  0.2879  0.81        0.0       3          13     16
# 1           1  0.22  0.2727  0.80        0.0       8          32     40
# 2           1  0.22  0.2727  0.80        0.0       5          27     32
# 3           1  0.24  0.2879  0.75        0.0       3          10     13
# 4           1  0.24  0.2879  0.75        0.0       0           1      1
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# ...
